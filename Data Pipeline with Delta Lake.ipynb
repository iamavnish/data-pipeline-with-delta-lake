# %% [markdown]
# **Project Scenario**: You are a Data Engineer working for an online clothing brand that sells a wide range of fashion Brands.
#
# The supply chain team has been tasked with building a dashboard to **Analyze Orders history**. Your dashboard will be used to inform purchasing behaviour and ensure that the company has enough inventory to meet demand for the upcoming holiday season.
#
# Throughout this real-world business scenario, you will learn how to create and ingest data into a delta table. Then use Databricks notebooks (using Python and SQL) to process/transform the data and produce the Supply chain dashboard. At the end you'll leverage Delta Lake's built-in functionalities such as merge operations and time travel to create a scalable data pipeline.

# %% [markdown]
# # TASK 1 - Upload project JSON files to Databricks file system

# %%
# First Check that the parameter "DBFS File Browser" is Enabled. Navigate to "Settings > Admin > Workspace settings"  to check

# %% [markdown]
# ### a. Upload ORDERS json files in Databricks File System

# %%
## Load Data Using the UI to this path dbfs:/FileStore/SupplyChain/ORDERS_RAW/
## Only upload these files: ORDERS_RAW_PART_001.json, ORDERS_RAW_PART_002.json, ORDERS_RAW_PART_003.json, ORDERS_RAW_PART_004.json

# %% [markdown]
# ### b. Check loaded files

# %%
# Use Databricks Utilities (dbutils). Documentation : https://docs.databricks.com/dev-tools/databricks-utils.html#ls-command-dbutilsfsls 
dbutils.fs.ls("dbfs:/FileStore/SupplyChain/ORDERS_RAW")
# Out:
# Out[5]: [FileInfo(path='dbfs:/FileStore/SupplyChain/ORDERS_RAW/ORDERS_RAW_PART_001.json', name='ORDERS_RAW_PART_001.json', size=260483, modificationTime=1719451817000),
#  FileInfo(path='dbfs:/FileStore/SupplyChain/ORDERS_RAW/ORDERS_RAW_PART_002.json', name='ORDERS_RAW_PART_002.json', size=260437, modificationTime=1719451817000),
#  FileInfo(path='dbfs:/FileStore/SupplyChain/ORDERS_RAW/ORDERS_RAW_PART_003.json', name='ORDERS_RAW_PART_003.json', size=260640, modificationTime=1719451818000),
#  FileInfo(path='dbfs:/FileStore/SupplyChain/ORDERS_RAW/ORDERS_RAW_PART_004.json', name='ORDERS_RAW_PART_004.json', size=4928, modificationTime=1719451818000),
#  FileInfo(path='dbfs:/FileStore/SupplyChain/ORDERS_RAW/UPDATE_ORDERS_RAW.json', name='UPDATE_ORDERS_RAW.json', size=2628, modificationTime=1719793248000)]

# %% [markdown]
# # TASK 2 - Create Delta Table : ORDERS_RAW

# %% [markdown]
# ### a. Read multiline json files using spark dataframe:

# %%
# Read multiple line json files using spark dataframeAPI


orders_raw_df = spark.read.option("multiline","true").json("dbfs:/FileStore/SupplyChain/ORDERS_RAW")

## Show the datafarme
orders_raw_df.show(n=5, truncate=False) 

## click on orders_raw_df to Check the schema
# Out:
# +---------------+-------------------+-----+-----------+-------------+----------+--------+------------+-----------------+-----------------------+--------+---------------+--------+------------+----------+
# |BRAND          |CATEGORY           |COLOR|CUSTOMER_ID|ORDER_COUNTRY|ORDER_DATE|ORDER_ID|ORDER_STATUS|PAYMENT_METHOD   |PRODUCT_NAME           |QUANTITY|SHIPPING_METHOD|SIZE    |SUB-CATEGORY|UNIT_PRICE|
# +---------------+-------------------+-----+-----------+-------------+----------+--------+------------+-----------------+-----------------------+--------+---------------+--------+------------+----------+
# |Gap            |Men's Clothing     |Navy |2348       |Germany      |2023-01-11|ORD-200 |Shipped     |Cash on Delivery |Classic Cotton T-Shirt |6       |Express        |Size L  |Tops        |24.99     |
# |Adidas Kids    |Kids Clothing      |Green|2149       |Mexico       |2023-01-11|ORD-1418|Delivered   |Credit/Debit Card|Green Hooded Sweatshirt|3       |Standard       |Size 14 |Tops        |44.99     |
# |Coach          |Women's Accessories|Black|2032       |Morocco      |2023-01-12|ORD-1185|Shipped     |Cash on Delivery |Leather Crossbody Bag  |2       |Express        |One Size|Bags        |199.99    |
# |Brooks Brothers|Men's Shoes        |Brown|2424       |Brazil       |2023-01-12|ORD-921 |Cancelled   |PayPal           |Brown Leather Loafers  |3       |Standard       |Size 10 |Loafers     |199.99    |
# |Gap Kids       |Kids Clothing      |White|2371       |Mexico       |2023-01-12|ORD-143 |Delivered   |Credit/Debit Card|White Lace Dress       |3       |Standard       |Size 5  |Dresses     |39.99     |
# +---------------+-------------------+-----+-----------+-------------+----------+--------+------------+-----------------+-----------------------+--------+---------------+--------+------------+----------+
# only showing top 5 rows

# %%
#Validate loaded files, Count Number of Rows in the DataFrame, the total Should be "1510"
orders_raw_df.count()
# Out:
# Out[8]: 1515

# %% [markdown]
# ### b. Create Delta Table ORDERS_RAW

# %% [markdown]
# Delta Lake is 100% compatible with Apache Spark&trade;, which makes it easy to get started with if you already use Spark for your big data workflows.
# Delta Lake features APIs for **SQL**, **Python**, and **Scala**, so that you can use it in whatever language you feel most comfortable in.
#
#
#    <img src="https://databricks.com/wp-content/uploads/2020/12/simplysaydelta.png" width=400/>

# %%
# First, Create Database SupplyChainDB if it doesn't exist
db = "SupplyChainDB"

spark.sql(f"CREATE DATABASE IF NOT EXISTS {db}")
spark.sql(f"USE {db}")
# Out:
# Out[9]: DataFrame[]

# %%
## Create DeltaTable ORDERS_RAW in the metastore using DataFrame's schema and write data to it
## Documentation : https://docs.delta.io/latest/quick-start.html#create-a-table
orders_raw_df.write.mode("overwrite").format("delta").option("overwriteSchema","true").saveAsTable("ORDERS_RAW")

# %% [markdown]
# ### c. Show Created Delta Table:

# %%
# %sql
-- Switch to SQL Cell using %SQL
SHOW tables
 
 -- Alternativerly you can use Python: display(spark.sql(f"SHOW TABLES"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>supplychaindb</td><td>orders_raw</td><td>false</td></tr></tbody></table></div>

# %% [markdown]
# **d. Validate data loaded successfully to Delta Table ORDERS_RAW**:

# %%
# %sql

select count(*) from orders_raw
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>1515</td></tr></tbody></table></div>

# %% [markdown]
# **e. Decsribe Detail of the Delta Table**:

# %%
# %sql

describe DETAIL ORDERS_RAW

-- Returns the basic metadata information of a delta table.
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>format</th><th>id</th><th>name</th><th>description</th><th>location</th><th>createdAt</th><th>lastModified</th><th>partitionColumns</th><th>numFiles</th><th>sizeInBytes</th><th>properties</th><th>minReaderVersion</th><th>minWriterVersion</th><th>tableFeatures</th><th>statistics</th></tr></thead><tbody><tr><td>delta</td><td>e0843de1-781a-4b8e-a5ca-d430920cb861</td><td>spark_catalog.supplychaindb.orders_raw</td><td>null</td><td>dbfs:/user/hive/warehouse/supplychaindb.db/orders_raw</td><td>2024-06-28T02:08:07.125+0000</td><td>2024-07-02T16:38:19.000+0000</td><td>List()</td><td>5</td><td>62631</td><td>Map()</td><td>1</td><td>2</td><td>List(appendOnly, invariants)</td><td>Map()</td></tr></tbody></table></div>

# %% [markdown]
# #Activity 1 : Create INVENTORY Delta table

# %% [markdown]
# ### a. Upload INVENTORY.json file in DBFS

# %%
## Load the file using the UI to this path dbfs:/FileStore/SupplyChain/INVENTORY/

# %% [markdown]
# ###b. Read the File using spark dataframe

# %%
inventory_df = spark.read.option("multiline","true").json("dbfs:/FileStore/SupplyChain/INVENTORY")

## Show the datafarme
inventory_df.show(n=5, truncate=False)
# Out:
# +-------+----------+--------------------------+----------+-----+
# |BRAND  |COLOR     |PRODUCT_NAME              |SIZE      |STOCK|
# +-------+----------+--------------------------+----------+-----+
# |J.Crew |Green     |Green Cargo Pants         |Size 32x32|58   |
# |Theory |Grey      |Grey Turtleneck Sweater   |Size S    |42   |
# |Ray-Ban|Gold/Brown|Classic Aviator Sunglasses|One Size  |53   |
# |ASOS   |Black     |Men's Faux Leather Jacket |Size M    |40   |
# |Levi's |Light Blue|Distressed Denim Shorts   |Size M    |46   |
# +-------+----------+--------------------------+----------+-----+
# only showing top 5 rows

# %% [markdown]
# ### c. Create Delta Table INVENTORY

# %%
# First, Create Database SupplyChainDB
db = "SupplyChainDB"
spark.sql(f"CREATE DATABASE IF NOT EXISTS {db}")
spark.sql(f"USE {db}")
# Out:
# Out[17]: DataFrame[]

# %%
## Create INVENTORY Delta Table 
inventory_df.write.mode("overwrite").format("delta").option("overwriteSchema","true").saveAsTable("INVENTORY")

# %% [markdown]
# ### d. Show Created Delta Tables:

# %%
# %sql
-- Switch to SQL Cell using %sql
SHOW TABLES
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>supplychaindb</td><td>inventory</td><td>false</td></tr><tr><td>supplychaindb</td><td>orders_raw</td><td>false</td></tr></tbody></table></div>

# %% [markdown]
# # TASK 3 - Transform data in delta table

# %% [markdown]
# <a href="https://www.databricks.com/glossary/medallion-architecture" target="_blank">Medallion Architecture</a>
# </br>
# <img src="https://databricks.com/wp-content/uploads/2020/09/delta-lake-medallion-model-scaled.jpg" width=900/>

# %% [markdown]
# During this Task you will :
# * 1- Read delta Table using Spark Dataframe
# * 2- Convert Data Type String --> Date
# * 3- Drop Rows with Null Values
# * 4- Add a Computed Column "TOTAL_ORDER"
# * 5- Create new deltatable Orders_Gold

# %% [markdown]
# ### a. Read ORDERS_RAW delta table using spark Dataframe

# %%
#read Delta Table using spark dataframe
#read orders_raw table into silver layer i.e orders_silver_df
ORDERS_Gold_df=  spark.read.table("supplychaindb.orders_raw")

ORDERS_Gold_df.show(n=5,truncate=False)
# Click on ORDERS_DF to See the Schema of the Table.
# Out:
# +------------+----------------+--------------+-----------+-------------+----------+--------+------------+-----------------+---------------------+--------+---------------+-------+------------+----------+
# |BRAND       |CATEGORY        |COLOR         |CUSTOMER_ID|ORDER_COUNTRY|ORDER_DATE|ORDER_ID|ORDER_STATUS|PAYMENT_METHOD   |PRODUCT_NAME         |QUANTITY|SHIPPING_METHOD|SIZE   |SUB-CATEGORY|UNIT_PRICE|
# +------------+----------------+--------------+-----------+-------------+----------+--------+------------+-----------------+---------------------+--------+---------------+-------+------------+----------+
# |H&M Kids    |Kids Clothing   |Pink and Green|2066       |Hong Kong    |2022-01-21|ORD-1281|Processing  |Credit/Debit Card|Pink Floral Dress    |3       |Standard       |Size 6 |Dresses     |24.99     |
# |H&M         |Women's Clothing|Cream         |2254       |Spain        |2022-01-23|ORD-541 |Delivered   |Credit/Debit Card|Women's Faux Fur Coat|4       |Standard       |Size M |Outerwear   |129.99    |
# |Canada Goose|Men's Clothing  |Dark Green    |2033       |Hong Kong    |2022-01-23|ORD-1388|Shipped     |Credit/Debit Card|Men's Parka          |2       |Standard       |Size XL|Jackets     |999.99    |
# |Zara Kids   |Kids Clothing   |Grey          |2144       |Switzerland  |2022-01-24|ORD-1158|Delivered   |Credit/Debit Card|Grey Hoodie          |1       |Standard       |Size L |Sweatshirts |39.99     |
# |Canada Goose|Men's Clothing  |Green         |2001       |Germany      |2022-01-24|ORD-1351|Shipped     |Credit/Debit Card|Green Parka          |2       |Standard       |Size L |Outerwear   |699.99    |
# +------------+----------------+--------------+-----------+-------------+----------+--------+------------+-----------------+---------------------+--------+---------------+-------+------------+----------+
# only showing top 5 rows

# %% [markdown]
# ### b. Update ORDER_DATE Column's Data Type

# %%
# Use withColumn method & to_date()
# withColumn Documentation : https://spark.apache.org/docs/3.1.3/api/python/reference/api/pyspark.sql.DataFrame.withColumn.html
# TO_DATE() Documentation : https://docs.databricks.com/sql/language-manual/functions/to_date.html

from pyspark.sql.functions import *


ORDERS_Gold_df =  ORDERS_Gold_df.withColumn("ORDER_DATE",to_date(col("ORDER_DATE"),"yyyy-MM-dd"))

# %% [markdown]
# ### c. Drop Rows with Null Values

# %%
# Count Nulls for each column
from pyspark.sql.functions import *

display(ORDERS_Gold_df.select([count(when(col(c).isNull(),c)).alias(c) for c in ORDERS_Gold_df.columns]))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>BRAND</th><th>CATEGORY</th><th>COLOR</th><th>CUSTOMER_ID</th><th>ORDER_COUNTRY</th><th>ORDER_DATE</th><th>ORDER_ID</th><th>ORDER_STATUS</th><th>PAYMENT_METHOD</th><th>PRODUCT_NAME</th><th>QUANTITY</th><th>SHIPPING_METHOD</th><th>SIZE</th><th>SUB-CATEGORY</th><th>UNIT_PRICE</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>0</td><td>10</td><td>10</td><td>0</td><td>10</td><td>0</td><td>0</td><td>10</td><td>10</td><td>0</td><td>0</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
#  Remove Nulls using dropna() method which removes all rows with Null Values 

ORDERS_Gold_df = ORDERS_Gold_df.dropna()

ORDERS_Gold_df.count()
# Out:
# Out[26]: 1505

# %% [markdown]
# ### d. Add new Column TOTAL_ORDER

# %%
#Use withColumn function
#Documentation : https://spark.apache.org/docs/3.1.3/api/python/reference/api/pyspark.sql.DataFrame.withColumn.html


ORDERS_Gold_df= ORDERS_Gold_df.withColumn("TOTAL_ORDER",col("QUANTITY")*col("UNIT_PRICE"))

# Display ORDERS_Gold_df to validate the creation of the New Column TOTAL_ORDER
display(ORDERS_Gold_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>BRAND</th><th>CATEGORY</th><th>COLOR</th><th>CUSTOMER_ID</th><th>ORDER_COUNTRY</th><th>ORDER_DATE</th><th>ORDER_ID</th><th>ORDER_STATUS</th><th>PAYMENT_METHOD</th><th>PRODUCT_NAME</th><th>QUANTITY</th><th>SHIPPING_METHOD</th><th>SIZE</th><th>SUB-CATEGORY</th><th>UNIT_PRICE</th><th>TOTAL_ORDER</th></tr></thead><tbody><tr><td>H&M Kids</td><td>Kids Clothing</td><td>Pink and Green</td><td>2066</td><td>Hong Kong</td><td>2022-01-21</td><td>ORD-1281</td><td>Processing</td><td>Credit/Debit Card</td><td>Pink Floral Dress</td><td>3</td><td>Standard</td><td>Size 6</td><td>Dresses</td><td>24.99</td><td>74.97</td></tr><tr><td>H&M</td><td>Women's Clothing</td><td>Cream</td><td>2254</td><td>Spain</td><td>2022-01-23</td><td>ORD-541</td><td>Delivered</td><td>Credit/Debit Card</td><td>Women's Faux Fur Coat</td><td>4</td><td>Standard</td><td>Size M</td><td>Outerwear</td><td>129.99</td><td>519.96</td></tr><tr><td>Canada Goose</td><td>Men's Clothing</td><td>Dark Green</td><td>2033</td><td>Hong Kong</td><td>2022-01-23</td><td>ORD-1388</td><td>Shipped</td><td>Credit/Debit Card</td><td>Men's Parka</td><td>2</td><td>Standard</td><td>Size XL</td><td>Jackets</td><td>999.99</td><td>1999.98</td></tr><tr><td>Zara Kids</td><td>Kids Clothing</td><td>Grey</td><td>2144</td><td>Switzerland</td><td>2022-01-24</td><td>ORD-1158</td><td>Delivered</td><td>Credit/Debit Card</td><td>Grey Hoodie</td><td>1</td><td>Standard</td><td>Size L</td><td>Sweatshirts</td><td>39.99</td><td>39.99</td></tr><tr><td>Canada Goose</td><td>Men's Clothing</td><td>Green</td><td>2001</td><td>Germany</td><td>2022-01-24</td><td>ORD-1351</td><td>Shipped</td><td>Credit/Debit Card</td><td>Green Parka</td><td>2</td><td>Standard</td><td>Size L</td><td>Outerwear</td><td>699.99</td><td>1399.98</td></tr><tr><td>Mango</td><td>Women's Clothing</td><td>Pink/White</td><td>2360</td><td>South Africa</td><td>2022-01-25</td><td>ORD-665</td><td>Delivered</td><td>Credit/Debit Card</td><td>Floral Midi Dress</td><td>2</td><td>Standard</td><td>Size 6</td><td>Dresses</td><td>148.0</td><td>296.0</td></tr><tr><td>H&M Kids</td><td>Kids Clothing</td><td>Orange</td><td>2128</td><td>Canada</td><td>2022-01-26</td><td>ORD-428</td><td>Cancelled</td><td>PayPal</td><td>Orange Cargo Shorts</td><td>5</td><td>Standard</td><td>Size 8</td><td>Shorts</td><td>22.99</td><td>114.94999999999999</td></tr><tr><td>Gap</td><td>Men's Clothing</td><td>Navy</td><td>2406</td><td>Egypt</td><td>2022-01-26</td><td>ORD-760</td><td>Shipped</td><td>Cash on Delivery</td><td>Classic Cotton T-Shirt</td><td>7</td><td>Express</td><td>Size L</td><td>Tops</td><td>24.99</td><td>174.92999999999998</td></tr><tr><td>Zara</td><td>Men's Clothing</td><td>Green</td><td>2365</td><td>Mexico</td><td>2022-01-26</td><td>ORD-384</td><td>Cancelled</td><td>PayPal</td><td>Green Utility Jacket</td><td>7</td><td>Standard</td><td>Size XL</td><td>Jackets</td><td>129.99</td><td>909.9300000000001</td></tr><tr><td>H&M Kids</td><td>Kids Clothing</td><td>Gray</td><td>2027</td><td>Italy</td><td>2022-01-27</td><td>ORD-567</td><td>Shipped</td><td>Credit/Debit Card</td><td>Gray Sweatshirt</td><td>5</td><td>Standard</td><td>Size 6</td><td>Tops</td><td>19.99</td><td>99.94999999999999</td></tr><tr><td>J.Crew</td><td>Men's Clothing</td><td>Green</td><td>2092</td><td>United Kingdom</td><td>2022-01-27</td><td>ORD-1590</td><td>Delivered</td><td>Credit/Debit Card</td><td>Green Cargo Pants</td><td>1</td><td>Standard</td><td>Size 32x32</td><td>Pants</td><td>89.99</td><td>89.99</td></tr><tr><td>Mango</td><td>Women's Clothing</td><td>Black</td><td>2023</td><td>Saudi Arabia</td><td>2022-01-28</td><td>ORD-829</td><td>Processing</td><td>Credit/Debit Card</td><td>Women's Leather Moto Jacket</td><td>3</td><td>Standard</td><td>Size S</td><td>Jackets</td><td>199.99</td><td>599.97</td></tr><tr><td>J.Crew</td><td>Women's Clothing</td><td>Grey</td><td>2127</td><td>Netherlands</td><td>2022- ...

# %% [markdown]
# ### e. Create Delta Table ORDERS_GOLD

# %%
# Make sure you are using SupplyChainDB
spark.sql(f"USE SupplyChainDB")

## Create DeltaTable Orders_GOLD: 

ORDERS_Gold_df.write.mode("overwrite").format("delta").option("overwriteSchema","true").saveAsTable("ORDERS_GOLD")


## Validate that the table was created successfully
display(spark.sql(f"SHOW TABLES"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>supplychaindb</td><td>inventory</td><td>false</td></tr><tr><td>supplychaindb</td><td>orders_gold</td><td>false</td></tr><tr><td>supplychaindb</td><td>orders_raw</td><td>false</td></tr></tbody></table></div>

# %% [markdown]
# -- Read more about different write options and parameters here https://docs.delta.io/latest/delta-batch.html#write-to-a-table
#
# * **Append** to automatically add new data to an existing Delta table,
# * **Overwrite** To automatically replace all the data in a table:

# %% [markdown]
# # TASK 5 - Query Orders Delta table using SQL

# %% [markdown]
# ### Get Familiar with Orders_Gold dataset

# %%
# %sql
-- Get top 30 rows Get Familiar with the Data
select * from supplychaindb.orders_gold limit 10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>BRAND</th><th>CATEGORY</th><th>COLOR</th><th>CUSTOMER_ID</th><th>ORDER_COUNTRY</th><th>ORDER_DATE</th><th>ORDER_ID</th><th>ORDER_STATUS</th><th>PAYMENT_METHOD</th><th>PRODUCT_NAME</th><th>QUANTITY</th><th>SHIPPING_METHOD</th><th>SIZE</th><th>SUB-CATEGORY</th><th>UNIT_PRICE</th><th>TOTAL_ORDER</th></tr></thead><tbody><tr><td>H&M Kids</td><td>Kids Clothing</td><td>Pink and Green</td><td>2066</td><td>Hong Kong</td><td>2022-01-21</td><td>ORD-1281</td><td>Processing</td><td>Credit/Debit Card</td><td>Pink Floral Dress</td><td>3</td><td>Standard</td><td>Size 6</td><td>Dresses</td><td>24.99</td><td>74.97</td></tr><tr><td>H&M</td><td>Women's Clothing</td><td>Cream</td><td>2254</td><td>Spain</td><td>2022-01-23</td><td>ORD-541</td><td>Delivered</td><td>Credit/Debit Card</td><td>Women's Faux Fur Coat</td><td>4</td><td>Standard</td><td>Size M</td><td>Outerwear</td><td>129.99</td><td>519.96</td></tr><tr><td>Canada Goose</td><td>Men's Clothing</td><td>Dark Green</td><td>2033</td><td>Hong Kong</td><td>2022-01-23</td><td>ORD-1388</td><td>Shipped</td><td>Credit/Debit Card</td><td>Men's Parka</td><td>2</td><td>Standard</td><td>Size XL</td><td>Jackets</td><td>999.99</td><td>1999.98</td></tr><tr><td>Zara Kids</td><td>Kids Clothing</td><td>Grey</td><td>2144</td><td>Switzerland</td><td>2022-01-24</td><td>ORD-1158</td><td>Delivered</td><td>Credit/Debit Card</td><td>Grey Hoodie</td><td>1</td><td>Standard</td><td>Size L</td><td>Sweatshirts</td><td>39.99</td><td>39.99</td></tr><tr><td>Canada Goose</td><td>Men's Clothing</td><td>Green</td><td>2001</td><td>Germany</td><td>2022-01-24</td><td>ORD-1351</td><td>Shipped</td><td>Credit/Debit Card</td><td>Green Parka</td><td>2</td><td>Standard</td><td>Size L</td><td>Outerwear</td><td>699.99</td><td>1399.98</td></tr><tr><td>Mango</td><td>Women's Clothing</td><td>Pink/White</td><td>2360</td><td>South Africa</td><td>2022-01-25</td><td>ORD-665</td><td>Delivered</td><td>Credit/Debit Card</td><td>Floral Midi Dress</td><td>2</td><td>Standard</td><td>Size 6</td><td>Dresses</td><td>148.0</td><td>296.0</td></tr><tr><td>H&M Kids</td><td>Kids Clothing</td><td>Orange</td><td>2128</td><td>Canada</td><td>2022-01-26</td><td>ORD-428</td><td>Cancelled</td><td>PayPal</td><td>Orange Cargo Shorts</td><td>5</td><td>Standard</td><td>Size 8</td><td>Shorts</td><td>22.99</td><td>114.94999999999999</td></tr><tr><td>Gap</td><td>Men's Clothing</td><td>Navy</td><td>2406</td><td>Egypt</td><td>2022-01-26</td><td>ORD-760</td><td>Shipped</td><td>Cash on Delivery</td><td>Classic Cotton T-Shirt</td><td>7</td><td>Express</td><td>Size L</td><td>Tops</td><td>24.99</td><td>174.92999999999998</td></tr><tr><td>Zara</td><td>Men's Clothing</td><td>Green</td><td>2365</td><td>Mexico</td><td>2022-01-26</td><td>ORD-384</td><td>Cancelled</td><td>PayPal</td><td>Green Utility Jacket</td><td>7</td><td>Standard</td><td>Size XL</td><td>Jackets</td><td>129.99</td><td>909.9300000000001</td></tr><tr><td>H&M Kids</td><td>Kids Clothing</td><td>Gray</td><td>2027</td><td>Italy</td><td>2022-01-27</td><td>ORD-567</td><td>Shipped</td><td>Credit/Debit Card</td><td>Gray Sweatshirt</td><td>5</td><td>Standard</td><td>Size 6</td><td>Tops</td><td>19.99</td><td>99.94999999999999</td></tr></tbody></table></div>

# %% [markdown]
# ### KPI-1: Quantity Sold by Country

# %%
# %sql
-- Division = CATEGORY 
-- Dont forget to Filter out Cancelled Orders
-- Avnish -- Put this data into Gold layer
select order_country, sum(quantity) as total_demand from orders_gold where order_status != 'Cancelled' group by order_country
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_country</th><th>total_demand</th></tr></thead><tbody><tr><td>Germany</td><td>278</td></tr><tr><td>France</td><td>243</td></tr><tr><td>Greece</td><td>252</td></tr><tr><td>India</td><td>229</td></tr><tr><td>United States</td><td>215</td></tr><tr><td>China</td><td>211</td></tr><tr><td>Italy</td><td>181</td></tr><tr><td>Norway</td><td>244</td></tr><tr><td>Spain</td><td>213</td></tr><tr><td>Denmark</td><td>185</td></tr><tr><td>Morocco</td><td>175</td></tr><tr><td>Hong Kong</td><td>192</td></tr><tr><td>Mexico</td><td>217</td></tr><tr><td>Tunisia</td><td>251</td></tr><tr><td>Saudi Arabia</td><td>260</td></tr><tr><td>Switzerland</td><td>263</td></tr><tr><td>United Arab Emirates</td><td>225</td></tr><tr><td>Canada</td><td>252</td></tr><tr><td>Brazil</td><td>253</td></tr><tr><td>Japan</td><td>230</td></tr><tr><td>Portugal</td><td>227</td></tr><tr><td>Egypt</td><td>145</td></tr><tr><td>South Africa</td><td>192</td></tr><tr><td>United Kingdom</td><td>170</td></tr><tr><td>Netherlands</td><td>236</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# ### KPI-2: Sales by Division ($)

# %%
# %sql
-- Dont forget to Filter out Cancelled Orders
select category, sum(total_order) as revenue from orders_gold where order_status != 'Cancelled' group by category order by revenue desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>category</th><th>revenue</th></tr></thead><tbody><tr><td>Men's Clothing</td><td>403902.19000000006</td></tr><tr><td>Women's Clothing</td><td>276763.86000000004</td></tr><tr><td>Accessories</td><td>99434.47000000002</td></tr><tr><td>Kids Clothing</td><td>85777.13999999997</td></tr><tr><td>Men's Shoes</td><td>50567.42</td></tr><tr><td>Men's Accessories</td><td>31758.91</td></tr><tr><td>Women's Accessories</td><td>21388.93</td></tr><tr><td>Women's Shoes</td><td>10349.130000000001</td></tr><tr><td>Unisex Accessories</td><td>6899.540000000001</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# ### KPI-3: Top-5 Popular Brands

# %%
# %sql
-- Limit Result to 5 and Order Results by Sold Quanity
select brand, sum(quantity) as total_sold_items from supplychaindb.orders_gold group by brand order by total_sold_items desc limit 5
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>brand</th><th>total_sold_items</th></tr></thead><tbody><tr><td>Mango</td><td>682</td></tr><tr><td>Coach</td><td>436</td></tr><tr><td>Zara</td><td>418</td></tr><tr><td>Nike Kids</td><td>381</td></tr><tr><td>H&M Kids</td><td>369</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# # TASK 6 - Create Dashboard

# %%
# Use Databricks UI
# 1- Turn results of Previous Queries into visualisations
# 2- Create Dashboard and add Visualisations

# %% [markdown]
# # Activity 2 : Add Monthly Sales Trend to your Dashboard

# %% [markdown]
# ### KPI-4: Monthly Sales Trend (In QTY)

# %% [markdown]
# ** Instructions :**
#   # 1- Query Delta Table: Orders_Gold to extract Monthly Sales (in Quantity, across all brands and all regions)
#   # 2- Turn the result (Table) into a visualisation (line chart) to Show the Trend for the last 18 months.
#   # 3- Add your visualization to the Supply Chain Dashboard.

# %%
# %sql
-- Use DATE_TRUNC()  
select date_trunc('month',order_date) as month, sum(quantity) as demand from supplychaindb.orders_gold 
where ORDER_STATUS != 'Cancelled'
group by 1 order by 1 asc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>month</th><th>demand</th></tr></thead><tbody><tr><td>2022-01-01T00:00:00.000+0000</td><td>71</td></tr><tr><td>2022-02-01T00:00:00.000+0000</td><td>156</td></tr><tr><td>2022-03-01T00:00:00.000+0000</td><td>192</td></tr><tr><td>2022-04-01T00:00:00.000+0000</td><td>167</td></tr><tr><td>2022-05-01T00:00:00.000+0000</td><td>200</td></tr><tr><td>2022-06-01T00:00:00.000+0000</td><td>198</td></tr><tr><td>2022-07-01T00:00:00.000+0000</td><td>433</td></tr><tr><td>2022-08-01T00:00:00.000+0000</td><td>332</td></tr><tr><td>2022-09-01T00:00:00.000+0000</td><td>479</td></tr><tr><td>2022-10-01T00:00:00.000+0000</td><td>456</td></tr><tr><td>2022-11-01T00:00:00.000+0000</td><td>392</td></tr><tr><td>2022-12-01T00:00:00.000+0000</td><td>400</td></tr><tr><td>2023-01-01T00:00:00.000+0000</td><td>413</td></tr><tr><td>2023-02-01T00:00:00.000+0000</td><td>396</td></tr><tr><td>2023-03-01T00:00:00.000+0000</td><td>539</td></tr><tr><td>2023-04-01T00:00:00.000+0000</td><td>360</td></tr><tr><td>2023-05-01T00:00:00.000+0000</td><td>241</td></tr><tr><td>2023-06-01T00:00:00.000+0000</td><td>114</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# # TASK 7 - Update Data in Orders table using Merge

# %% [markdown]
# <img src="https://databricks.com/wp-content/uploads/2020/09/delta-lake-medallion-model-scaled.jpg" width=1012/>

# %% [markdown]
# ### a. Upload json files into DBFS

# %% [markdown]
# Use UI to upload the file "UPDATE_ORDERS_RAW.json" into DBFS, use the same folder dbfs:/FileStore/SupplyChain/ORDERS_RAW/

# %% [markdown]
# ### b. Read file using Spark dataframe

# %%
# Read multiple line json file UPDATE_ORDERS_RAW.json
Update_orders_df = spark.read.option("multiline","true").json("dbfs:/FileStore/SupplyChain/ORDERS_RAW/UPDATE_ORDERS_RAW.json")

## Show the datafarme
display(Update_orders_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>BRAND</th><th>CATEGORY</th><th>COLOR</th><th>CUSTOMER_ID</th><th>ORDER_COUNTRY</th><th>ORDER_DATE</th><th>ORDER_ID</th><th>ORDER_STATUS</th><th>PAYMENT_METHOD</th><th>PRODUCT_NAME</th><th>QUANTITY</th><th>SHIPPING_METHOD</th><th>SIZE</th><th>SUB-CATEGORY</th><th>UNIT_PRICE</th></tr></thead><tbody><tr><td>H&M Kids</td><td>Kids Clothing</td><td>Pink and Green</td><td>2066</td><td>Hong Kong</td><td>2022-01-21</td><td>ORD-1281</td><td>Delivered</td><td>Credit/Debit Card</td><td>Pink Floral Dress</td><td>4</td><td>Standard</td><td>Size 6</td><td>Dresses</td><td>24.99</td></tr><tr><td>Mango</td><td>Women's Clothing</td><td>Black</td><td>2023</td><td>Saudi Arabia</td><td>2022-01-28</td><td>ORD-829</td><td>Delivered</td><td>Credit/Debit Card</td><td>Women's Leather Moto Jacket</td><td>3</td><td>Standard</td><td>Size S</td><td>Jackets</td><td>199.99</td></tr><tr><td>Madewell</td><td>Women's Clothing</td><td>Blue</td><td>2041</td><td>Saudi Arabia</td><td>2022-01-28</td><td>ORD-193</td><td>Delivered</td><td>Cash on Delivery</td><td>Blue Denim Jacket</td><td>3</td><td>Standard</td><td>Size M</td><td>Jackets</td><td>99.99</td></tr><tr><td>Barbour</td><td>Men's Clothing</td><td>Navy</td><td>2074</td><td>Norway</td><td>2022-05-29</td><td>ORD-826</td><td>Cancelled</td><td>Credit/Debit Card</td><td>Men's Quilted Jacket</td><td>0</td><td>Standard</td><td>Size L</td><td>Jackets</td><td>299.99</td></tr><tr><td>Gap Kids</td><td>Kids Clothing</td><td>Red</td><td>2393</td><td>Saudi Arabia</td><td>2022-05-30</td><td>ORD-842</td><td>Cancelled</td><td>Credit/Debit Card</td><td>Red Graphic T-shirt</td><td>0</td><td>Standard</td><td>Size 8</td><td>Tops</td><td>14.99</td></tr></tbody></table></div>

# %% [markdown]
# -->Check the original data **BEFORE MERGE**

# %%
# %sql 
select ORDER_ID,ORDER_STATUS,Quantity from Supplychaindb.ORDERS_RAW WHERE ORDER_ID in ("ORD-1281","ORD-829","ORD-193","ORD-826","ORD-842")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ORDER_ID</th><th>ORDER_STATUS</th><th>Quantity</th></tr></thead><tbody><tr><td>ORD-1281</td><td>Processing</td><td>3</td></tr><tr><td>ORD-829</td><td>Processing</td><td>3</td></tr><tr><td>ORD-193</td><td>Shipped</td><td>1</td></tr><tr><td>ORD-826</td><td>Processing</td><td>10</td></tr><tr><td>ORD-842</td><td>Processing</td><td>10</td></tr><tr><td>ORD-1281</td><td>Delivered</td><td>4</td></tr><tr><td>ORD-829</td><td>Delivered</td><td>3</td></tr><tr><td>ORD-193</td><td>Delivered</td><td>3</td></tr><tr><td>ORD-826</td><td>Cancelled</td><td>0</td></tr><tr><td>ORD-842</td><td>Cancelled</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# ### c. Update Orders_RAW delta table using Merge

# %%
# %sql
DESCRIBE DETAIL supplychaindb.ORDERS_RAW
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>format</th><th>id</th><th>name</th><th>description</th><th>location</th><th>createdAt</th><th>lastModified</th><th>partitionColumns</th><th>numFiles</th><th>sizeInBytes</th><th>properties</th><th>minReaderVersion</th><th>minWriterVersion</th><th>tableFeatures</th><th>statistics</th></tr></thead><tbody><tr><td>delta</td><td>e0843de1-781a-4b8e-a5ca-d430920cb861</td><td>spark_catalog.supplychaindb.orders_raw</td><td>null</td><td>dbfs:/user/hive/warehouse/supplychaindb.db/orders_raw</td><td>2024-06-28T02:08:07.125+0000</td><td>2024-07-02T00:18:13.000+0000</td><td>List()</td><td>5</td><td>62631</td><td>Map()</td><td>1</td><td>2</td><td>List(appendOnly, invariants)</td><td>Map()</td></tr></tbody></table></div>

# %%
from delta.tables import *

# programmatically interacting with Delta tables using the class delta.tables.DeltaTable(spark: pyspark.sql.session.SparkSession, jdt: JavaObject)
# delta_orders_raw is a dataframe
delta_orders_raw =  DeltaTable.forPath(spark,'dbfs:/user/hive/warehouse/supplychaindb.db/orders_raw')

# %%
## merge data into delta Table ORDER_RAW
# DOCUMENTATION https://docs.delta.io/latest/delta-update.html#language-python 

delta_orders_raw.alias("ORDERS_RAW").merge(Update_orders_df.alias("UpdateOrders"),
                                           "ORDERS_RAW.ORDER_ID = UpdateOrders.ORDER_ID")\
                                           .whenMatchedUpdateAll()\
                                           .whenNotMatchedInsertAll()\
                                          .execute()
                                          

# must be at least one WHEN clause in a MERGE statement.

# %% [markdown]
# --> check the udapted rows **AFTER MERGE**

# %%
# %sql 
select ORDER_ID,ORDER_STATUS,Quantity from SUPPLYCHAINDB.ORDERS_RAW WHERE ORDER_ID in ("ORD-1281","ORD-829","ORD-193","ORD-826","ORD-842")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ORDER_ID</th><th>ORDER_STATUS</th><th>Quantity</th></tr></thead><tbody><tr><td>ORD-1281</td><td>Delivered</td><td>4</td></tr><tr><td>ORD-1281</td><td>Delivered</td><td>4</td></tr><tr><td>ORD-829</td><td>Delivered</td><td>3</td></tr><tr><td>ORD-829</td><td>Delivered</td><td>3</td></tr><tr><td>ORD-193</td><td>Delivered</td><td>3</td></tr><tr><td>ORD-193</td><td>Delivered</td><td>3</td></tr><tr><td>ORD-826</td><td>Cancelled</td><td>0</td></tr><tr><td>ORD-826</td><td>Cancelled</td><td>0</td></tr><tr><td>ORD-842</td><td>Cancelled</td><td>0</td></tr><tr><td>ORD-842</td><td>Cancelled</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# Learn More about Merge Operations check out https://docs.delta.io/latest/delta-update.html#language-python

# %% [markdown]
# # TASK 8 - Query previous versions of delta table using **Time Travel**

# %% [markdown]
# **This Task shows how to time travel between different versions of a Delta table with Delta Lake. You can time travel by table version or by timestamp. You’ll learn about the benefits of time travel and why it’s an essential feature for production data workloads.**
#
# **Documentation : https://delta.io/blog/2023-02-01-delta-lake-time-travel/**
#
# <img src="https://delta.io/static/9c42ea9f028932de03257ed75d35a8ba/cf8e5/image1.png" width=1012/>

# %% [markdown]
# ### a. Describe Detla Table History:

# %%
# %sql
-- Check Table History 
describe history supplychaindb.orders_raw
-- Use the UI to see Delta Table History
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>18</td><td>2024-07-02T00:19:43.000+0000</td><td>6874844908570099</td><td>avnishlearnsgcp@gmail.com</td><td>MERGE</td><td>Map(predicate -> ["(ORDER_ID#6432 = ORDER_ID#6163)"], matchedPredicates -> [{"actionType":"update"}], notMatchedPredicates -> [{"actionType":"insert"}], notMatchedBySourcePredicates -> [])</td><td>null</td><td>List(2136992527233995)</td><td>0702-001426-nmbhsymn</td><td>17</td><td>WriteSerializable</td><td>false</td><td>Map(numTargetRowsCopied -> 495, numTargetRowsDeleted -> 0, numTargetFilesAdded -> 2, numTargetBytesAdded -> 23040, numTargetBytesRemoved -> 22856, numTargetDeletionVectorsAdded -> 0, numTargetRowsMatchedUpdated -> 10, executionTimeMs -> 10274, numTargetRowsInserted -> 0, numTargetRowsMatchedDeleted -> 0, scanTimeMs -> 4274, numTargetRowsUpdated -> 10, numOutputRows -> 505, numTargetDeletionVectorsRemoved -> 0, numTargetRowsNotMatchedBySourceUpdated -> 0, numTargetChangeFilesAdded -> 0, numSourceRows -> 5, numTargetFilesRemoved -> 2, numTargetRowsNotMatchedBySourceDeleted -> 0, rewriteTimeMs -> 5090)</td><td>null</td><td>Databricks-Runtime/12.2.x-scala2.12</td></tr><tr><td>17</td><td>2024-07-02T00:18:13.000+0000</td><td>6874844908570099</td><td>avnishlearnsgcp@gmail.com</td><td>CREATE OR REPLACE TABLE AS SELECT</td><td>Map(isManaged -> true, description -> null, partitionBy -> [], properties -> {})</td><td>null</td><td>List(2136992527233995)</td><td>0702-001426-nmbhsymn</td><td>16</td><td>WriteSerializable</td><td>false</td><td>Map(numFiles -> 5, numOutputRows -> 1515, numOutputBytes -> 62631)</td><td>null</td><td>Databricks-Runtime/12.2.x-scala2.12</td></tr><tr><td>16</td><td>2024-07-01T16:57:51.000+0000</td><td>6874844908570099</td><td>avnishlearnsgcp@gmail.com</td><td>MERGE</td><td>Map(predicate -> ["(ORDER_ID#23439 = ORDER_ID#23170)"], matchedPredicates -> [{"actionType":"update"}], notMatchedPredicates -> [{"actionType":"insert"}], notMatchedBySourcePredicates -> [])</td><td>null</td><td>List(2136992527233995)</td><td>0701-160550-3l4hvbag</td><td>15</td><td>WriteSerializable</td><td>false</td><td>Map(numTargetRowsCopied -> 495, numTargetRowsDeleted -> 0, numTargetFilesAdded -> 2, numTargetBytesAdded -> 23040, numTargetBytesRemoved -> 22856, numTargetDeletionVectorsAdded -> 0, numTargetRowsMatchedUpdated -> 10, executionTimeMs -> 4907, numTargetRowsInserted -> 0, numTargetRowsMatchedDeleted -> 0, scanTimeMs -> 1812, numTargetRowsUpdated -> 10, numOutputRows -> 505, numTargetDeletionVectorsRemoved -> 0, numTargetRowsNotMatchedBySourceUpdated -> 0, numTargetChangeFilesAdded -> 0, numSourceRows -> 5, numTargetFilesRemoved -> 2, numTargetRowsNotMatchedBySourceDeleted -> 0, rewriteTimeMs -> 2691)</td><td>null</td><td>Databricks-Runtime/12.2.x-scala2.12</td></tr><tr><td>15</td><td>2024-07-01T16:57:08.000+0000</td><td>6874844908570099</td><td>avnishlearnsgcp@gmail.com</td><td>CREATE OR REPLACE TABLE AS SELECT</td><td>Map(isManaged -> true, description -> null, partitionBy -> [], properties -> {})</td><td>null</td><td>List(2136992527233995)</td><td>0701-160550-3l4hvbag</td><td>14</td><td>WriteSerializable</td><td>false</td><td>Map(numFiles -> 5, numOutputRows -> 1515, numOutputBytes -> 62631)</td><td>null</td><td>Databricks-Runtime/12.2.x-scala2.12</td></tr><tr><td>14</td><td>2024-07-01T16:46:09.000+0000</td><td>6874844908570099</td><td>avnishlearnsgcp@gmail.com</td><td>MERGE</td><td>Map(predicate -> ["(ORDER_ID#15490 = ORDER_ID#15221)"], matchedPredicates -> [{"actionType":"update"}], notMatchedPredicates -> [{"actionType":"insert"}], notMatchedBySourcePredicates -> [])</td ...

# %% [markdown]
# ### b. Using SQL:

# %%
# %sql 
 select ORDER_ID,ORDER_STATUS,Quantity from SUPPLYCHAINDB.ORDERS_RAW VERSION AS OF 5 WHERE ORDER_ID in ("ORD-1281","ORD-829","ORD-193","ORD-826","ORD-842")

-- CHange Version Number to See different Versions of the delta table
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ORDER_ID</th><th>ORDER_STATUS</th><th>Quantity</th></tr></thead><tbody><tr><td>ORD-1281</td><td>Processing</td><td>3</td></tr><tr><td>ORD-829</td><td>Processing</td><td>3</td></tr><tr><td>ORD-193</td><td>Shipped</td><td>1</td></tr><tr><td>ORD-826</td><td>Processing</td><td>10</td></tr><tr><td>ORD-842</td><td>Processing</td><td>10</td></tr><tr><td>ORD-1281</td><td>Delivered</td><td>4</td></tr><tr><td>ORD-829</td><td>Delivered</td><td>3</td></tr><tr><td>ORD-193</td><td>Delivered</td><td>3</td></tr><tr><td>ORD-826</td><td>Cancelled</td><td>0</td></tr><tr><td>ORD-842</td><td>Cancelled</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# ### c. Using Spark dataframe:

# %%
#Time Travel
version_1 = spark.read.format('delta').option('TimeStamp', "2023-05-16").table("SUPPLYCHAINDB.ORDERS_RAW")
display(version_1)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>BRAND</th><th>CATEGORY</th><th>COLOR</th><th>CUSTOMER_ID</th><th>ORDER_COUNTRY</th><th>ORDER_DATE</th><th>ORDER_ID</th><th>ORDER_STATUS</th><th>PAYMENT_METHOD</th><th>PRODUCT_NAME</th><th>QUANTITY</th><th>SHIPPING_METHOD</th><th>SIZE</th><th>SUB-CATEGORY</th><th>UNIT_PRICE</th></tr></thead><tbody><tr><td>H&M</td><td>Women's Clothing</td><td>Cream</td><td>2254</td><td>Spain</td><td>2022-01-23</td><td>ORD-541</td><td>Delivered</td><td>Credit/Debit Card</td><td>Women's Faux Fur Coat</td><td>4</td><td>Standard</td><td>Size M</td><td>Outerwear</td><td>129.99</td></tr><tr><td>Canada Goose</td><td>Men's Clothing</td><td>Dark Green</td><td>2033</td><td>Hong Kong</td><td>2022-01-23</td><td>ORD-1388</td><td>Shipped</td><td>Credit/Debit Card</td><td>Men's Parka</td><td>2</td><td>Standard</td><td>Size XL</td><td>Jackets</td><td>999.99</td></tr><tr><td>Zara Kids</td><td>Kids Clothing</td><td>Grey</td><td>2144</td><td>Switzerland</td><td>2022-01-24</td><td>ORD-1158</td><td>Delivered</td><td>Credit/Debit Card</td><td>Grey Hoodie</td><td>1</td><td>Standard</td><td>Size L</td><td>Sweatshirts</td><td>39.99</td></tr><tr><td>Canada Goose</td><td>Men's Clothing</td><td>Green</td><td>2001</td><td>Germany</td><td>2022-01-24</td><td>ORD-1351</td><td>Shipped</td><td>Credit/Debit Card</td><td>Green Parka</td><td>2</td><td>Standard</td><td>Size L</td><td>Outerwear</td><td>699.99</td></tr><tr><td>Mango</td><td>Women's Clothing</td><td>Pink/White</td><td>2360</td><td>South Africa</td><td>2022-01-25</td><td>ORD-665</td><td>Delivered</td><td>Credit/Debit Card</td><td>Floral Midi Dress</td><td>2</td><td>Standard</td><td>Size 6</td><td>Dresses</td><td>148.0</td></tr><tr><td>H&M Kids</td><td>Kids Clothing</td><td>Orange</td><td>2128</td><td>Canada</td><td>2022-01-26</td><td>ORD-428</td><td>Cancelled</td><td>PayPal</td><td>Orange Cargo Shorts</td><td>5</td><td>Standard</td><td>Size 8</td><td>Shorts</td><td>22.99</td></tr><tr><td>Gap</td><td>Men's Clothing</td><td>Navy</td><td>2406</td><td>Egypt</td><td>2022-01-26</td><td>ORD-760</td><td>Shipped</td><td>Cash on Delivery</td><td>Classic Cotton T-Shirt</td><td>7</td><td>Express</td><td>Size L</td><td>Tops</td><td>24.99</td></tr><tr><td>Zara</td><td>Men's Clothing</td><td>Green</td><td>2365</td><td>Mexico</td><td>2022-01-26</td><td>ORD-384</td><td>Cancelled</td><td>PayPal</td><td>Green Utility Jacket</td><td>7</td><td>Standard</td><td>Size XL</td><td>Jackets</td><td>129.99</td></tr><tr><td>H&M Kids</td><td>Kids Clothing</td><td>Gray</td><td>2027</td><td>Italy</td><td>2022-01-27</td><td>ORD-567</td><td>Shipped</td><td>Credit/Debit Card</td><td>Gray Sweatshirt</td><td>5</td><td>Standard</td><td>Size 6</td><td>Tops</td><td>19.99</td></tr><tr><td>J.Crew</td><td>Men's Clothing</td><td>Green</td><td>2092</td><td>United Kingdom</td><td>2022-01-27</td><td>ORD-1590</td><td>Delivered</td><td>Credit/Debit Card</td><td>Green Cargo Pants</td><td>1</td><td>Standard</td><td>Size 32x32</td><td>Pants</td><td>89.99</td></tr><tr><td>J.Crew</td><td>Women's Clothing</td><td>Grey</td><td>2127</td><td>Netherlands</td><td>2022-01-28</td><td>ORD-1163</td><td>Shipped</td><td>Credit/Debit Card</td><td>Grey Knit Sweater</td><td>2</td><td>Standard</td><td>Size L</td><td>Sweaters</td><td>89.99</td></tr><tr><td>Brooks Brothers</td><td>Men's Shoes</td><td>Brown</td><td>2271</td><td>Greece</td><td>2022-01-29</td><td>ORD-641</td><td>Delivered</td><td>Credit/Debit Card</td><td>Brown Leather Loafers</td><td>3</td><td>Standard</td><td>Size 10</td><td>Loafers</td><td>199.99</td></tr><tr><td>Mango</td><td>Men's Clothing</td><td>Red/Blue</td><td>2101</td><td>Norway</td><td>2022-01-29</td><td>ORD-1332</td><td>Delivered</td><td>Credit/Debit Card</td><td>Checkered Button-Down Shirt</td><td>2</td><td>Standard</td><td>Size L</td><td>Tops</td><td>49.99</td></tr><tr><td>Nike Kids</td><td>Kids Clothing</td><td>Purple</td><td>2253</td><td>Spain</ ...

# %% [markdown]
# # END OF THE PROJECT

# %% [markdown]
# # CUMULATIVE CHALLENGE

# %% [markdown]
# **Your Task :</br> Using the “Inventory” data, your task is to enrich the Supply Chain Dashboard with the list of low-stock and out-of-stock Items.**
#
# Using Databricks notebook you will : </br>
# 1-Upload INVENTORY.JSON file to DBFS(1) </br>
# 2-Read the file using spark dataframe (1)</br>
# 3-Create Delta Table INVENTORY (1)</br>
# 4-Write an SQL query to join ORDERS_GOLD and INVENTORY DeltaTables to find the list of Items Low-in Stock or Out-of Stock</br>
# 5-Turn the result into a Visualisation (Table type) and Add it to your SupplyChain Dashboard</br>

# %% [markdown]
# ### a. Upload INVENTORY.json file in DBFS

# %%
## Load the file using the UI to this path dbfs:/FileStore/SupplyChain/INVENTORY/

# %% [markdown]
# ### b. Read the File using spark dataframe

# %%
inventory_df = spark.read.option("multiline","true").json("dbfs:/FileStore/SupplyChain/INVENTORY")

## Show the datafarme
inventory_df.show(n=5, truncate=False)
# Out:
# +-------+----------+--------------------------+----------+-----+
# |BRAND  |COLOR     |PRODUCT_NAME              |SIZE      |STOCK|
# +-------+----------+--------------------------+----------+-----+
# |J.Crew |Green     |Green Cargo Pants         |Size 32x32|58   |
# |Theory |Grey      |Grey Turtleneck Sweater   |Size S    |42   |
# |Ray-Ban|Gold/Brown|Classic Aviator Sunglasses|One Size  |53   |
# |ASOS   |Black     |Men's Faux Leather Jacket |Size M    |40   |
# |Levi's |Light Blue|Distressed Denim Shorts   |Size M    |46   |
# +-------+----------+--------------------------+----------+-----+
# only showing top 5 rows

# %% [markdown]
# ### c. Create Delta Table INVENTORY <img src="https://pages.databricks.com/rs/094-YMS-629/images/delta-lake-tiny-logo.png" width=35 height=35/>

# %%
# Use SupplyChainDB Database
db = "SupplyChainDB"
spark.sql(f"USE {db}")
# Out:
# Out[40]: DataFrame[]

# %%
## Create INVENTORY Delta Table 
inventory_df.write.mode("overwrite").format("delta").option("overwriteSchema","true").saveAsTable("INVENTORY")

## Validate that the table was created successfully
display(spark.sql(f"SHOW TABLES"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>supplychaindb</td><td>inventory</td><td>false</td></tr><tr><td>supplychaindb</td><td>orders_gold</td><td>false</td></tr><tr><td>supplychaindb</td><td>orders_raw</td><td>false</td></tr></tbody></table></div>

# %% [markdown]
# ### d. Join ORDERS_GOLD and INVENTORY DeltaTables to find the list of Low Stock or Out-of Stock Items

# %% [markdown]
# **Your Goal** is to find the list of Low-Stock or Out-of-Stock Items and Add the result to your SupplyChain Dashboard<br />
# **Hints:**
# * Group all Orders (from ORDERS_GOLD) based-on BRAND, COLOR, PRODUCT_NAME AND SIZE And Add QTY_SOLD (SUM QUANTITY)
# * Join the result with INVENTORY using an inner join on BRAND, PRODUCT_NAME, COLOR AND SIZE.
# * Add calculated column "QTY_LEFT_STOCK" as (STOCK - QTY_SOLD)
# * Filter-out Cancelled ORDERS (ORDER_STATUS)
# * Keep only Items with QTY_LEFT_STOCK < 20
# * Sort the result by "QTY_LEFT_STOCK" in ascending order

# %%
# %sql
-- Write Your Query Here : 
select J.* from
(select O.*, I.stock, (I.STOCK - O.qty_sold) as QTY_LEFT_STOCK from 
(select brand, color, product_name, size, sum(quantity) as qty_sold
from supplychaindb.orders_gold
where ORDER_STATUS != 'Cancelled'
group by brand, color, product_name, size) O
join supplychaindb.inventory I
on (O.brand = I.BRAND)
and (O.product_name = I.PRODUCT_NAME)
and (O.color = I.COLOR)
and (O.size = I.SIZE)) J
where J.QTY_LEFT_STOCK < 20
order by J.QTY_LEFT_STOCK asc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>brand</th><th>color</th><th>product_name</th><th>size</th><th>qty_sold</th><th>stock</th><th>QTY_LEFT_STOCK</th></tr></thead><tbody><tr><td>ASOS</td><td>Black</td><td>Men's Faux Leather Jacket</td><td>Size M</td><td>37</td><td>40</td><td>3</td></tr><tr><td>Gap</td><td>Navy</td><td>Classic Cotton T-Shirt</td><td>Size L</td><td>40</td><td>44</td><td>4</td></tr><tr><td>Theory</td><td>Grey</td><td>Grey Turtleneck Sweater</td><td>Size S</td><td>37</td><td>42</td><td>5</td></tr><tr><td>J.Crew</td><td>Green</td><td>Green Cargo Pants</td><td>Size 32x32</td><td>52</td><td>58</td><td>6</td></tr><tr><td>Ray-Ban</td><td>Gold/Brown</td><td>Classic Aviator Sunglasses</td><td>One Size</td><td>46</td><td>53</td><td>7</td></tr><tr><td>Steve Madden</td><td>Black</td><td>Lace-Up Combat Boots</td><td>Size 8</td><td>55</td><td>65</td><td>10</td></tr><tr><td>Levi's</td><td>Light Blue</td><td>Distressed Denim Shorts</td><td>Size M</td><td>36</td><td>46</td><td>10</td></tr><tr><td>Coach</td><td>Black</td><td>Leather Crossbody Bag</td><td>One Size</td><td>40</td><td>53</td><td>13</td></tr><tr><td>Nike Kids</td><td>Gray</td><td>Gray Joggers</td><td>Size 12</td><td>36</td><td>50</td><td>14</td></tr><tr><td>Dr. Martens</td><td>Black</td><td>Black Leather Chelsea Boots</td><td>Size 10</td><td>45</td><td>61</td><td>16</td></tr><tr><td>Zara Kids</td><td>Red and Black</td><td>Red Plaid Button-Up Shirt</td><td>Size 4</td><td>42</td><td>59</td><td>17</td></tr><tr><td>H&M Kids</td><td>Green</td><td>Green Camo Pants</td><td>Size 5</td><td>42</td><td>59</td><td>17</td></tr><tr><td>Zara</td><td>Olive Green</td><td>Men's Bomber Jacket</td><td>Size L</td><td>44</td><td>62</td><td>18</td></tr><tr><td>Allen Edmonds</td><td>Brown</td><td>Brown Leather Belt</td><td>Size 34</td><td>37</td><td>55</td><td>18</td></tr><tr><td>H&M Kids</td><td>Orange</td><td>Orange Cargo Shorts</td><td>Size 8</td><td>26</td><td>44</td><td>18</td></tr><tr><td>Gap Kids</td><td>Pink</td><td>Pink Floral Dress</td><td>Size 6</td><td>44</td><td>63</td><td>19</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# ### e. Turn the result into a Visualisation (Table) and Add it to SupplyChain Dashboard
